# %%
# Import Dependencies
import pandas as pd

# %%
hawaii_flights_2019 = "2019_Q1_T_DB1B_MARKET.csv"

# %%
hawaii_flights_2019_df = pd.read_csv(hawaii_flights_2019)

hawaii_flights_2019_df.head(5)
# Out:
#     ITIN_ID      MKT_ID  YEAR  QUARTER  ORIGIN_AIRPORT_ID  \
# 0  20191204  2019120401  2019        1              10135
# 1  20191204  2019120403  2019        1              12173
# 2  20191705  2019170501  2019        1              10185
# 3  20191706  2019170604  2019        1              12982
# 4  20191706  2019170601  2019        1              10185
#
#    ORIGIN_AIRPORT_SEQ_ID  ORIGIN_CITY_MARKET_ID ORIGIN ORIGIN_STATE_ABR  \
# 0                1013505                  30135    ABE               PA
# 1                1217305                  32134    HNL               HI
# 2                1018502                  30185    AEX               LA
# 3                1298202                  32982    LIH               HI
# 4                1018502                  30185    AEX               LA
#
#   ORIGIN_STATE_NM  ...  DEST_CITY_MARKET_ID  DEST  DEST_STATE_ABR  \
# 0    Pennsylvania  ...                32134   HNL              HI
# ...

# %%
hawaii_flights_2019_df
# Out:
#              ITIN_ID          MKT_ID  YEAR  QUARTER  ORIGIN_AIRPORT_ID  \
# 0           20191204      2019120401  2019        1              10135
# 1           20191204      2019120403  2019        1              12173
# 2           20191705      2019170501  2019        1              10185
# 3           20191706      2019170604  2019        1              12982
# 4           20191706      2019170601  2019        1              10185
# ...              ...             ...   ...      ...                ...
# 235866  201915258032  20191525803203  2019        1              12173
# 235867  201915258063  20191525806301  2019        1              15919
# 235868  201915258063  20191525806303  2019        1              13830
# 235869  201915258083  20191525808301  2019        1              15919
# 235870  201915258083  20191525808304  2019        1              12173
#
#         ORIGIN_AIRPORT_SEQ_ID  ORIGIN_CITY_MARKET_ID ORIGIN ORIGIN_STATE_ABR  \
# ...

# %%
hawaii_flights_2019_df.columns
# Out:
# Index(['ITIN_ID', 'MKT_ID', 'YEAR', 'QUARTER', 'ORIGIN_AIRPORT_ID',
#        'ORIGIN_AIRPORT_SEQ_ID', 'ORIGIN_CITY_MARKET_ID', 'ORIGIN',
#        'ORIGIN_STATE_ABR', 'ORIGIN_STATE_NM', 'DEST_AIRPORT_ID',
#        'DEST_AIRPORT_SEQ_ID', 'DEST_CITY_MARKET_ID', 'DEST', 'DEST_STATE_ABR',
#        'DEST_STATE_NM', 'TK_CARRIER_GROUP', 'OP_CARRIER_GROUP',
#        'REPORTING_CARRIER', 'OPERATING_CARRIER', 'PASSENGERS', 'MARKET_FARE'],
#       dtype='object')
